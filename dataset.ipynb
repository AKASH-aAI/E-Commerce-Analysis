# %%
import pandas as pd 

df = pd.read_csv('ecommerce_sales_data.csv')

# %%
df.columns
# Out:
# Index(['TransactionID', 'CustomerID', 'ProductID', 'ProductCategory',
#        'Quantity', 'Price', 'Discount', 'TransactionDate', 'PaymentMethod',
#        'CustomerLocation', 'CustomerAge', 'CustomerGender',
#        'CustomerIncomeGroup', 'CustomerLoyaltyScore'],
#       dtype='str')

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "mysql+pymysql://root:akash99110@localhost/ecommerce"
)

df.to_sql(
    name='ecommerce_data',
    con=engine,
    if_exists='append',
    index=False
)

print('data sended succesfully')
# Out:
# data sended succesfully
